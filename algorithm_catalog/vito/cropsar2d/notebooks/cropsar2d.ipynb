# %%
# import necessary packages
import openeo

# connect with the backend
eoconn = openeo.connect(
       "openeo.terrascope.be"
        ).authenticate_oidc()

# %%
# Setup process parameters
aoi = {
        "type": "Polygon",
        "coordinates": [
          [
            [
              5.179324150085449,
              51.2498689148547
            ],
            [
              5.178744792938232,
              51.24672597710759
            ],
            [
              5.185289382934569,
              51.24504696935156
            ],
            [
              5.18676996231079,
              51.245342479161295
            ],
            [
              5.187370777130127,
              51.24918393390799
            ],
            [
              5.179324150085449,
              51.2498689148547
            ]
          ]
        ]
      }
date = ["2024-06-01", "2024-06-30"]
biopar = "FAPAR"

# Create a processing graph from the CropSAR process using an active openEO connection
cropsar = eoconn.datacube_from_process(
          "cropsar2d", 
          namespace="https://raw.githubusercontent.com/ESA-APEx/apex_algorithms/f23a5f1ec3f5a67f1dc45b5abaae9ef61858124d/algorithm_catalog/vito/cropsar2d/openeo_udp/cropsar2d.json",
          geometry=aoi,
          startdate = date[0],
          enddate = date[1],
          output=biopar
          )

# %%
job = cropsar.create_job(
                title="Cropsar2D job example", 
                job_options = {
                "udf-dependency-archives": [
                    "https://s3.waw3-1.cloudferro.com/project_dependencies/onnx_deps_python311.zip#onnx_deps",
                ],
                },
                out_format="NetCDF"
                )
job.start_and_wait()
# Out:
# 0:00:00 Job 'j-26071007433944ca995e8eb90c602db4': send 'start'
# 0:00:43 Job 'j-26071007433944ca995e8eb90c602db4': queued (progress 0%)
# 0:00:51 Job 'j-26071007433944ca995e8eb90c602db4': queued (progress 0%)
# 0:00:57 Job 'j-26071007433944ca995e8eb90c602db4': queued (progress 0%)
# 0:01:05 Job 'j-26071007433944ca995e8eb90c602db4': queued (progress 0%)
# 0:01:19 Job 'j-26071007433944ca995e8eb90c602db4': queued (progress 0%)
# 0:01:32 Job 'j-26071007433944ca995e8eb90c602db4': queued (progress 0%)
# 0:01:51 Job 'j-26071007433944ca995e8eb90c602db4': running (progress 10.4%)
# 0:02:10 Job 'j-26071007433944ca995e8eb90c602db4': running (progress 13.0%)
# 0:02:34 Job 'j-26071007433944ca995e8eb90c602db4': running (progress 15.9%)
# 0:03:04 Job 'j-26071007433944ca995e8eb90c602db4': running (progress 19.3%)
# 0:03:42 Job 'j-26071007433944ca995e8eb90c602db4': running (progress 23.2%)
# 0:04:29 Job 'j-26071007433944ca995e8eb90c602db4': running (progress 27.5%)
# ...

# %%
results = job.get_results()
results.download_files("cropsar2d_output/")
# Out:
# [WindowsPath('cropsar2d_output/openEO.nc'),
#  WindowsPath('cropsar2d_output/job-results.json')]
