# %%
# import necessary packages
import openeo

# connect with the backend
eoconn = openeo.connect(
       "openeo.terrascope.be"
        ).authenticate_oidc()
# Out:
# Authenticated using refresh token.

# %%
# Setup process parameters
aoi = {
        "type": "Polygon",
        "coordinates": [
          [
            [
              5.179324150085449,
              51.2498689148547
            ],
            [
              5.178744792938232,
              51.24672597710759
            ],
            [
              5.185289382934569,
              51.24504696935156
            ],
            [
              5.18676996231079,
              51.245342479161295
            ],
            [
              5.187370777130127,
              51.24918393390799
            ],
            [
              5.179324150085449,
              51.2498689148547
            ]
          ]
        ]
      }
date = "2024-06-01", "2024-06-30"
biopar = "FAPAR"

# Create a processing graph from the CropSAR process using an active openEO connection
cropsar = eoconn.datacube_from_process(
          "cropsar2d", 
          namespace="https://raw.githubusercontent.com/ESA-APEx/apex_algorithms/92171ae86087fe8ddde737292032cd1fff167a3f/algorithm_catalog/vito/cropsar2d/openeo_udp/cropsar2d.json",
          geometry=aoi,
          startdate = date[0],
          enddate = date[1],
          output=biopar
          )

# %%
job = cropsar.create_job(
                title="Cropsar2D job example", 
                job_options = {
                "udf-dependency-archives": [
                    "https://s3.waw3-1.cloudferro.com/project_dependencies/onnx_deps_python311.zip#onnx_deps",
                ],
                },
                out_format="NetCDF"
                )
job.start_and_wait()
# Out:
# 0:00:00 Job 'j-26061207060740428b54498d531e77b2': send 'start'
# 0:01:30 Job 'j-26061207060740428b54498d531e77b2': queued (progress 0%)
# 0:02:00 Job 'j-26061207060740428b54498d531e77b2': queued (progress 0%)
# 0:02:06 Job 'j-26061207060740428b54498d531e77b2': queued (progress 0%)
# 0:02:14 Job 'j-26061207060740428b54498d531e77b2': running (progress 7.6%)
# 0:02:29 Job 'j-26061207060740428b54498d531e77b2': running (progress 9.6%)
# 0:02:41 Job 'j-26061207060740428b54498d531e77b2': running (progress 11.3%)
# 0:02:57 Job 'j-26061207060740428b54498d531e77b2': running (progress 13.3%)
# 0:03:16 Job 'j-26061207060740428b54498d531e77b2': running (progress 15.6%)
# 0:03:40 Job 'j-26061207060740428b54498d531e77b2': running (progress 18.4%)
# 0:04:10 Job 'j-26061207060740428b54498d531e77b2': running (progress 21.5%)
# 0:04:47 Job 'j-26061207060740428b54498d531e77b2': running (progress 25.2%)
# 0:05:34 Job 'j-26061207060740428b54498d531e77b2': running (progress 29.3%)
# 0:06:32 Job 'j-26061207060740428b54498d531e77b2': running (progress 33.9%)
# 0:07:39 Job 'j-26061207060740428b54498d531e77b2': running (progress 38.4%)
# 0:08:39 Job 'j-26061207060740428b54498d531e77b2': finished (progress 100%)
# <BatchJob job_id='j-26061207060740428b54498d531e77b2'>

# %%
results = job.get_results()
results.download_files("cropsar2d_output/")
# Out:
# [PosixPath('cropsar2d_output/openEO.nc'),
#  PosixPath('cropsar2d_output/job-results.json')]
